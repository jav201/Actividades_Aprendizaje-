# %% [markdown]
# <a href="https://colab.research.google.com/github/jav201/Actividades_Aprendizaje-/blob/main/Python%20for%20Data%20Science%20(IBM)%207.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A00566717
# José Javier Granados Hernández

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
